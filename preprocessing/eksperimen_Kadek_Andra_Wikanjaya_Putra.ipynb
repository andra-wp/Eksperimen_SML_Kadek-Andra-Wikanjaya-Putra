# %%
import pandas as pd
from automate_Kadek_Andra_Wikanjaya_Putra import preprocessing
from membangun_model.modelling import modelling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 from automate_Kadek_Andra_Wikanjaya_Putra import preprocessing
# ----> 3 from membangun_model.modelling import modelling
#
# ModuleNotFoundError: No module named 'membangun_model'

# %%
df = pd.read_csv('../diabetes_raw/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_final = preprocessing(df)
df_final.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age   Outcome
# 0                  0.468492  1.425995  1.365896
# 1                 -0.365061 -0.190672 -0.732120
# 2                  0.604397 -0.105584  1.365896
# 3                 -0.920763 -1.041549 -0.732120
# 4                  5.484909 -0.020496  1.365896
